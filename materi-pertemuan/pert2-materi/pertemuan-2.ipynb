# %% [markdown]
# # Pertemuan 2 — Logika, Perulangan, dan Function
#
# Notebook hasil hands-on pertemuan 2. Ikuti tiap cell berurutan dari atas ke bawah. Detail penjelasan tiap langkah ada di `README.md` pertemuan ini.

# %% [markdown]
# ## Langkah 1 — Mengecek Stok dengan if

# %%
stok = int(input("Masukkan jumlah stok: "))

if stok > 0:
    print("Barang tersedia")

# %%
uang = int(input("Masukkan jumlah uang: "))

if uang > 0:
    print("Gas jajan !")

# %% [markdown]
# ## Langkah 2 — if/else: Dua Jalur

# %%
stok = int(input("Masukkan jumlah stok: "))

if stok > 0:
    print("Barang tersedia")
else:
    print("Stok habis")

# %%
game = input("Masukkan game untuk main: ")

if game == "Roblox":
    print("Gassss Rosbloxxx")
else:
    print(f"Kuy mabar game {game} !")

# %% [markdown]
# ## Langkah 3 — if/elif/else: Diskon Toko

# %%
total_belanja = 175000

if total_belanja >= 200000:
    diskon = 0.15
elif total_belanja >= 100000:
    diskon = 0.10
else:
    diskon = 0

print(f"Diskon: {diskon:.0%}")

# %%
money = int(input("Masukkan jumlah uang: "))

if money >= 20000000:
    print("Bisa beli Laptop Gaming!")
elif money >= 15000000:
    print("Bisa beli Rakit PC!")
elif money >= 8000000:
    print("Bisa beli PS5!")
elif money >= 1000000:
    print("Bisa beli GTA 6!")
else:
    print("MISKIN !!!!")

# %% [markdown]
# ## Langkah 4 — Sengaja Salah Indentasi
#
# Cell di bawah ini SENGAJA menghasilkan error, supaya terbiasa membaca `IndentationError`.

# %%
total_belanja = 175000
if total_belanja >= 100000:
print("Dapat diskon!")

# %% [markdown]
# Perbaikannya: baris di dalam `if` wajib menjorok.

# %%
total_belanja = 175000
if total_belanja >= 100000:
    print("Dapat diskon!")

# %% [markdown]
# #### Name Error

# %%
print(yourname)

# %%
yourname = input("Masukkan nama anda: ")
print(f"nama mu adalah {yourname}")

# %% [markdown]
# #### Type Error

# %%
umur_teks = "20"
umur = umur_teks + 5
print(umur)

# %% [markdown]
# ## Langkah 5 — Operator Logika: Syarat Promo

# %%
member = True
total_belanja = 120000

if member and total_belanja >= 100000:
    print("Dapat promo member!")
else:
    print("Belum memenuhi syarat promo")

# %% [markdown]
# ## Langkah 6 — for pada List Kategori

# %%
kategori = ["Elektronik", "Fashion", "Makanan", "Buku", "Olahraga"]

for nama in kategori:
    print(nama)

# %% [markdown]
# ## Langkah 7 — for dengan range()

# %%
for i in range(1, 5):
    print(i)

# %%
for i in range(1, 10, 2):
    print(i)

# %% [markdown]
# ## Langkah 8 — enumerate(): Penjualan Harian

# %%
penjualan = [120, 80, 150]

for nomor, nilai in enumerate(penjualan, start=1):
    print(f"Hari {nomor}: {nilai} transaksi")

# %% [markdown]
# ## Langkah 9 — Akumulasi: Total Penjualan

# %%
penjualan = [120000, 85000, 200000]
total = 0

for nilai in penjualan:
    total += nilai

print(f"Total penjualan: {total}")

# %% [markdown]
# ## Langkah 10 — while: Kejar Target Penjualan

# %%
target = 500000
total_terkumpul = 0
hari = 0

while total_terkumpul < target:
    total_terkumpul += 100000
    hari += 1

print(f"Target tercapai dalam {hari} hari")

# %%
import random

angka_rahasia = random.randint(1, 10)

while True:
    tebakan = int(input("Tebak angka 1-10: "))
    if tebakan == angka_rahasia:
        print("Benar! Angka nya", angka_rahasia)
        break
    elif tebakan < angka_rahasia:
        print("Kurang tinggi, coba lagi")
    else:
        print("Kurang rendah, coba lagi")

# %% [markdown]
# ## Langkah 11 — break: Berhenti Saat Stok Habis

# %%
stok = [5, 3, 0, 8]

for jumlah in stok:
    if jumlah == 0:
        break
    print(f"Sisa stok: {jumlah}")

# %% [markdown]
# ## Langkah 12 — continue: Lewati Data Kosong

# %%
penjualan_harian = [120000, 0, 95000, 0, 200000]

for nilai in penjualan_harian:
    if nilai == 0:
        continue
    print(f"Transaksi: {nilai}")

# %% [markdown]
# ## Langkah 13 — Function Pertama Tanpa Parameter

# %%
def output():
    print("Selamat datang di Isekai")

output()

# %% [markdown]
# ## Langkah 14 — Function dengan Parameter dan return

# %%
def hitung_total(harga, jumlah):
    return harga * jumlah

hasil = hitung_total(15000, 3)
print(hasil)

# %%
def luas_lingkaran(jari_jari):
    return 3.14 * jari_jari * jari_jari

def luas_persegi_panjang(panjang, lebar):
    return panjang * lebar

print(luas_lingkaran(7))
print(luas_persegi_panjang(5, 3))

# %% [markdown]
# ## Langkah 15 — Default Parameter

# %%
def hitung_diskon(total, persen=0.10):
    return total * persen

print(hitung_diskon(200000))
print(hitung_diskon(200000, 0.20))

# %%
def cek_kalori(kalori_terpakai, batas_kalori=2000):
    sisa = batas_kalori - kalori_terpakai
    if sisa > 0:
        return f"Masih boleh mukbang, sisa kalori: {sisa}"
    else:
        return "Stop! Kalori udah kesentuh batas"

print(cek_kalori(1500))
print(cek_kalori(2000))
print(cek_kalori(2300))

# %% [markdown]
# ## Langkah 16 — Beda print() dan return

# %%
def tampilkan_saja(nilai):
    print(nilai * 2)

def kembalikan_nilai(nilai):
    return nilai * 2

hasil_print = tampilkan_saja(10)
hasil_return = kembalikan_nilai(10)

print("Nilai dari tampilkan_saja():", hasil_print)
print("Nilai dari kembalikan_nilai():", hasil_return)

# %% [markdown]
# ## Langkah 17 — Gabungan: Kategori Penjualan untuk Semua Data

# %%
def kategori_penjualan(nilai):
    if nilai < 100000:
        return "Rendah"
    elif nilai < 500000:
        return "Sedang"
    else:
        return "Tinggi"

penjualan = [50000, 120000, 600000, 95000, 300000]

for nilai in penjualan:
    print(f"{nilai} -> {kategori_penjualan(nilai)}")

# %% [markdown]
# ## Langkah 18 — List Comprehension

# %%
penjualan = [50000, 120000, 600000, 95000, 300000]
hasil_kategori = [kategori_penjualan(nilai) for nilai in penjualan]

print(hasil_kategori)

# %% [markdown]
# ## Langkah 19 — Coba Sendiri
#
# Buat function `cek_stok(jumlah)` yang mengembalikan `"Perlu restock"` kalau `jumlah` kurang dari `10`, selain itu `"Stok aman"`. Panggil untuk angka `5` dan `20`, tebak dulu hasilnya sebelum run.

# %%
# Tulis jawabanmu di sini

# %% [markdown]
# ## Langkah 20 — Sekilas OOP: Class Produk

# %%
class Produk:
    def __init__(self, nama, harga):
        self.nama = nama
        self.harga = harga

    def info(self):
        return f"{self.nama} - Rp {self.harga}"

produk1 = Produk("Headset", 250000)
produk2 = Produk("Mouse", 150000)

print(produk1.info())
print(produk2.info())

# %% [markdown]
# ## Selesai
#
# Notebook ini menutup pertemuan 2. Lanjut ke `kuis-latihan-2.md`/`pilgan-2.md` untuk latihan mandiri, atau ke pertemuan 3 untuk NumPy, Pandas, dan mengolah data CSV.
